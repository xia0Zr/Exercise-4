# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time

# Define cards
cards = [
    {"name": "Diablo", "health": 100, "attack": 90, "defense": 60},
    {"name": "Medusa", "health": 100, "attack": 70, "defense": 70},
    {"name": "Jester", "health": 120, "attack": 60, "defense": 90},
    {"name": "Troll", "health": 150, "attack": 40, "defense": 94},
    {"name": "Specter", "health": 100, "attack": 70, "defense": 70},
    {"name": "Mist", "health": 100, "attack": 75, "defense": 65},
    {"name": "Savage", "health": 100, "attack": 90, "defense": 50},
    {"name": "Marauder", "health": 100, "attack": 85, "defense": 50},
    {"name": "Wimp", "health": 110, "attack": 40, "defense": 85},
    {"name": "Sorcerer", "health": 100, "attack": 70, "defense": 55}
]

# Function: Display card info
def display_card(card):
    print(f"Card: {card['name']} | Health: {card['health']} | Attack: {card['attack']} | Defense: {card['defense']}")

# Function: Battle logic
def battle(player_card, opponent_card):
    print("\n--- Battle Starts ---")
    print("Player's card:")
    display_card(player_card)
    print("Opponent's card:")
    display_card(opponent_card)

    # Player attacks opponent
    if player_card['attack'] > opponent_card['health']:
        print(f"\nPlayer's {player_card['name']} defeats the opponent's {opponent_card['name']} in one hit!")
        return True
    else:
        print(f"\n{player_card['name']} attacks {opponent_card['name']}!")

        damage_to_defense = 0  # Initialize damage_to_defense
        
        if opponent_card['defense'] > 0:
            damage_to_defense = min(player_card['attack'], opponent_card['defense'])
            opponent_card['defense'] -= damage_to_defense
            print(f"{opponent_card['name']}'s defense is reduced by {damage_to_defense}, remaining defense: {opponent_card['defense']}")
        
        remaining_attack = player_card['attack'] - damage_to_defense
        
        if remaining_attack > 0:
            opponent_card['health'] -= remaining_attack
            print(f"{opponent_card['name']}'s health is reduced by {remaining_attack}, remaining health: {opponent_card['health']}")
        
        if opponent_card['health'] <= 0:
            print(f"\n{opponent_card['name']} is defeated!")
            return True
        else:
            return False

# Function: Initialize decks
def initialize_decks():
    player_deck = random.sample(cards, 5)
    opponent_deck = random.sample(cards, 5)
    return player_deck, opponent_deck

# Function: Start the game
def start_game():
    print("\nWelcome to the Card Battle RPG!")
    player_deck, opponent_deck = initialize_decks()

    # Continue the game until either deck is empty
    while player_deck and opponent_deck:
        print("\n--- Player's Deck ---")
        for idx, card in enumerate(player_deck):
            print(f"{idx+1}: {card['name']} (Health: {card['health']}, Attack: {card['attack']}, Defense: {card['defense']})")
        
        # Player selects a card
        choice = int(input(f"\nChoose a card to battle (1-{len(player_deck)}): ")) - 1
        player_card = player_deck[choice]

        # Opponent randomly selects a card
        opponent_card = random.choice(opponent_deck)

        # Battle
        if battle(player_card, opponent_card):
            opponent_deck.remove(opponent_card)
        else:
            print("\nNow it's the opponent's turn...")
            time.sleep(2)
            if battle(opponent_card, player_card):
                player_deck.remove(player_card)

        time.sleep(2)

    if not opponent_deck:
        print("\nCongratulations! You won!")
    elif not player_deck:
        print("\nSorry, you lost!")

start_game()
# Out:
# Welcome to the Card Battle RPG!
#
# --- Player's Deck ---
# 1: Specter (Health: 100, Attack: 70, Defense: 70)
# 2: Troll (Health: 150, Attack: 40, Defense: 94)
# 3: Mist (Health: 100, Attack: 75, Defense: 65)
# 4: Medusa (Health: 100, Attack: 70, Defense: 70)
# 5: Savage (Health: 100, Attack: 90, Defense: 50)
#
# --- Battle Starts ---
# Player's card:
# Card: Specter | Health: 100 | Attack: 70 | Defense: 70
# Opponent's card:
# Card: Medusa | Health: 100 | Attack: 70 | Defense: 70
#
# Specter attacks Medusa!
# Medusa's defense is reduced by 70, remaining defense: 0
#
# Now it's the opponent's turn...
#
# --- Battle Starts ---
# Player's card:
# Card: Medusa | Health: 100 | Attack: 70 | Defense: 0
# Opponent's card:
# Card: Specter | Health: 100 | Attack: 70 | Defense: 70
#
# Medusa attacks Specter!
# Specter's defense is reduced by 70, remaining defense: 0
#
# --- Player's Deck ---
# 1: Specter (Health: 100, Attack: 70, Defense: 0)
# 2: Troll (Health: 150, Attack: 40, Defense: 94)
# 3: Mist (Health: 100, Attack: 75, Defense: 65)
# 4: Medusa (Health: 100, Attack: 70, Defense: 0)
# 5: Savage (Health: 100, Attack: 90, Defense: 50)
#
# --- Battle Starts ---
# Player's card:
# Card: Troll | Health: 150 | Attack: 40 | Defense: 94
# Opponent's card:
# Card: Wimp | Health: 110 | Attack: 40 | Defense: 85
#
# Troll attacks Wimp!
# Wimp's defense is reduced by 40, remaining defense: 45
#
# Now it's the opponent's turn...
#
# --- Battle Starts ---
# Player's card:
# Card: Wimp | Health: 110 | Attack: 40 | Defense: 45
# Opponent's card:
# Card: Troll | Health: 150 | Attack: 40 | Defense: 94
#
# Wimp attacks Troll!
# Troll's defense is reduced by 40, remaining defense: 54
#
# --- Player's Deck ---
# 1: Specter (Health: 100, Attack: 70, Defense: 0)
# 2: Troll (Health: 150, Attack: 40, Defense: 54)
# 3: Mist (Health: 100, Attack: 75, Defense: 65)
# 4: Medusa (Health: 100, Attack: 70, Defense: 0)
# 5: Savage (Health: 100, Attack: 90, Defense: 50)
#
# --- Battle Starts ---
# Player's card:
# Card: Troll | Health: 150 | Attack: 40 | Defense: 54
# Opponent's card:
# Card: Medusa | Health: 100 | Attack: 70 | Defense: 0
#
# Troll attacks Medusa!
# Medusa's health is reduced by 40, remaining health: 60
#
# Now it's the opponent's turn...
#
# --- Battle Starts ---
# Player's card:
# Card: Medusa | Health: 60 | Attack: 70 | Defense: 0
# Opponent's card:
# Card: Troll | Health: 150 | Attack: 40 | Defense: 54
#
# Medusa attacks Troll!
# Troll's defense is reduced by 54, remaining defense: 0
# Troll's health is reduced by 16, remaining health: 134
#
# --- Player's Deck ---
# 1: Specter (Health: 100, Attack: 70, Defense: 0)
# 2: Troll (Health: 134, Attack: 40, Defense: 0)
# 3: Mist (Health: 100, Attack: 75, Defense: 65)
# 4: Medusa (Health: 60, Attack: 70, Defense: 0)
# 5: Savage (Health: 100, Attack: 90, Defense: 50)
#
# --- Battle Starts ---
# Player's card:
# Card: Mist | Health: 100 | Attack: 75 | Defense: 65
# Opponent's card:
# Card: Wimp | Health: 110 | Attack: 40 | Defense: 45
#
# Mist attacks Wimp!
# Wimp's defense is reduced by 45, remaining defense: 0
# Wimp's health is reduced by 30, remaining health: 80
#
# Now it's the opponent's turn...
#
# --- Battle Starts ---
# Player's card:
# Card: Wimp | Health: 80 | Attack: 40 | Defense: 0
# Opponent's card:
# Card: Mist | Health: 100 | Attack: 75 | Defense: 65
#
# Wimp attacks Mist!
# Mist's defense is reduced by 40, remaining defense: 25
#
# --- Player's Deck ---
# 1: Specter (Health: 100, Attack: 70, Defense: 0)
# 2: Troll (Health: 134, Attack: 40, Defense: 0)
# 3: Mist (Health: 100, Attack: 75, Defense: 25)
# 4: Medusa (Health: 60, Attack: 70, Defense: 0)
# 5: Savage (Health: 100, Attack: 90, Defense: 50)
#
# --- Battle Starts ---
# Player's card:
# Card: Mist | Health: 100 | Attack: 75 | Defense: 25
# Opponent's card:
# Card: Wimp | Health: 80 | Attack: 40 | Defense: 0
#
# Mist attacks Wimp!
# Wimp's health is reduced by 75, remaining health: 5
#
# Now it's the opponent's turn...
#
# --- Battle Starts ---
# Player's card:
# Card: Wimp | Health: 5 | Attack: 40 | Defense: 0
# Opponent's card:
# Card: Mist | Health: 100 | Attack: 75 | Defense: 25
#
# Wimp attacks Mist!
# Mist's defense is reduced by 25, remaining defense: 0
# Mist's health is reduced by 15, remaining health: 85
#
# --- Player's Deck ---
# 1: Specter (Health: 100, Attack: 70, Defense: 0)
# 2: Troll (Health: 134, Attack: 40, Defense: 0)
# 3: Mist (Health: 85, Attack: 75, Defense: 0)
# 4: Medusa (Health: 60, Attack: 70, Defense: 0)
# 5: Savage (Health: 100, Attack: 90, Defense: 50)
#
# --- Battle Starts ---
# Player's card:
# Card: Savage | Health: 100 | Attack: 90 | Defense: 50
# Opponent's card:
# Card: Medusa | Health: 60 | Attack: 70 | Defense: 0
#
# Player's Savage defeats the opponent's Medusa in one hit!
#
# --- Player's Deck ---
# 1: Specter (Health: 100, Attack: 70, Defense: 0)
# 2: Troll (Health: 134, Attack: 40, Defense: 0)
# 3: Mist (Health: 85, Attack: 75, Defense: 0)
# 4: Medusa (Health: 60, Attack: 70, Defense: 0)
# 5: Savage (Health: 100, Attack: 90, Defense: 50)
#
# --- Battle Starts ---
# Player's card:
# Card: Savage | Health: 100 | Attack: 90 | Defense: 50
# Opponent's card:
# Card: Jester | Health: 120 | Attack: 60 | Defense: 90
#
# Savage attacks Jester!
# Jester's defense is reduced by 90, remaining defense: 0
#
# Now it's the opponent's turn...
#
# --- Battle Starts ---
# Player's card:
# Card: Jester | Health: 120 | Attack: 60 | Defense: 0
# Opponent's card:
# Card: Savage | Health: 100 | Attack: 90 | Defense: 50
#
# Jester attacks Savage!
# Savage's defense is reduced by 50, remaining defense: 0
# Savage's health is reduced by 10, remaining health: 90
#
# --- Player's Deck ---
# 1: Specter (Health: 100, Attack: 70, Defense: 0)
# 2: Troll (Health: 134, Attack: 40, Defense: 0)
# 3: Mist (Health: 85, Attack: 75, Defense: 0)
# 4: Medusa (Health: 60, Attack: 70, Defense: 0)
# 5: Savage (Health: 90, Attack: 90, Defense: 0)
#
# --- Battle Starts ---
# Player's card:
# Card: Specter | Health: 100 | Attack: 70 | Defense: 0
# Opponent's card:
# Card: Wimp | Health: 5 | Attack: 40 | Defense: 0
#
# Player's Specter defeats the opponent's Wimp in one hit!
#
# --- Player's Deck ---
# 1: Specter (Health: 100, Attack: 70, Defense: 0)
# 2: Troll (Health: 134, Attack: 40, Defense: 0)
# 3: Mist (Health: 85, Attack: 75, Defense: 0)
# 4: Medusa (Health: 60, Attack: 70, Defense: 0)
# 5: Savage (Health: 90, Attack: 90, Defense: 0)
#
# --- Battle Starts ---
# Player's card:
# Card: Specter | Health: 100 | Attack: 70 | Defense: 0
# Opponent's card:
# Card: Sorcerer | Health: 100 | Attack: 70 | Defense: 55
#
# Specter attacks Sorcerer!
# Sorcerer's defense is reduced by 55, remaining defense: 0
# Sorcerer's health is reduced by 15, remaining health: 85
#
# Now it's the opponent's turn...
#
# --- Battle Starts ---
# Player's card:
# Card: Sorcerer | Health: 85 | Attack: 70 | Defense: 0
# Opponent's card:
# Card: Specter | Health: 100 | Attack: 70 | Defense: 0
#
# Sorcerer attacks Specter!
# Specter's health is reduced by 70, remaining health: 30
#
# --- Player's Deck ---
# 1: Specter (Health: 30, Attack: 70, Defense: 0)
# 2: Troll (Health: 134, Attack: 40, Defense: 0)
# 3: Mist (Health: 85, Attack: 75, Defense: 0)
# 4: Medusa (Health: 60, Attack: 70, Defense: 0)
# 5: Savage (Health: 90, Attack: 90, Defense: 0)
#
# --- Battle Starts ---
# Player's card:
# Card: Troll | Health: 134 | Attack: 40 | Defense: 0
# Opponent's card:
# Card: Jester | Health: 120 | Attack: 60 | Defense: 0
#
# Troll attacks Jester!
# Jester's health is reduced by 40, remaining health: 80
#
# Now it's the opponent's turn...
#
# --- Battle Starts ---
# Player's card:
# Card: Jester | Health: 80 | Attack: 60 | Defense: 0
# Opponent's card:
# Card: Troll | Health: 134 | Attack: 40 | Defense: 0
#
# Jester attacks Troll!
# Troll's health is reduced by 60, remaining health: 74
#
# --- Player's Deck ---
# 1: Specter (Health: 30, Attack: 70, Defense: 0)
# 2: Troll (Health: 74, Attack: 40, Defense: 0)
# 3: Mist (Health: 85, Attack: 75, Defense: 0)
# 4: Medusa (Health: 60, Attack: 70, Defense: 0)
# 5: Savage (Health: 90, Attack: 90, Defense: 0)
#
# --- Battle Starts ---
# Player's card:
# Card: Mist | Health: 85 | Attack: 75 | Defense: 0
# Opponent's card:
# Card: Diablo | Health: 100 | Attack: 90 | Defense: 60
#
# Mist attacks Diablo!
# Diablo's defense is reduced by 60, remaining defense: 0
# Diablo's health is reduced by 15, remaining health: 85
#
# Now it's the opponent's turn...
#
# --- Battle Starts ---
# Player's card:
# Card: Diablo | Health: 85 | Attack: 90 | Defense: 0
# Opponent's card:
# Card: Mist | Health: 85 | Attack: 75 | Defense: 0
#
# Player's Diablo defeats the opponent's Mist in one hit!
#
# --- Player's Deck ---
# 1: Specter (Health: 30, Attack: 70, Defense: 0)
# 2: Troll (Health: 74, Attack: 40, Defense: 0)
# 3: Medusa (Health: 60, Attack: 70, Defense: 0)
# 4: Savage (Health: 90, Attack: 90, Defense: 0)
#
# --- Battle Starts ---
# Player's card:
# Card: Savage | Health: 90 | Attack: 90 | Defense: 0
# Opponent's card:
# Card: Sorcerer | Health: 85 | Attack: 70 | Defense: 0
#
# Player's Savage defeats the opponent's Sorcerer in one hit!
#
# --- Player's Deck ---
# 1: Specter (Health: 30, Attack: 70, Defense: 0)
# 2: Troll (Health: 74, Attack: 40, Defense: 0)
# 3: Medusa (Health: 60, Attack: 70, Defense: 0)
# 4: Savage (Health: 90, Attack: 90, Defense: 0)
#
# --- Battle Starts ---
# Player's card:
# Card: Savage | Health: 90 | Attack: 90 | Defense: 0
# Opponent's card:
# Card: Jester | Health: 80 | Attack: 60 | Defense: 0
#
# Player's Savage defeats the opponent's Jester in one hit!
#
# --- Player's Deck ---
# 1: Specter (Health: 30, Attack: 70, Defense: 0)
# 2: Troll (Health: 74, Attack: 40, Defense: 0)
# 3: Medusa (Health: 60, Attack: 70, Defense: 0)
# 4: Savage (Health: 90, Attack: 90, Defense: 0)
#
# --- Battle Starts ---
# Player's card:
# Card: Savage | Health: 90 | Attack: 90 | Defense: 0
# Opponent's card:
# Card: Diablo | Health: 85 | Attack: 90 | Defense: 0
#
# Player's Savage defeats the opponent's Diablo in one hit!
#
# Congratulations! You won!
